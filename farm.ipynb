# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/upflairs-pvt-ltd/JECRC-20april2024/main/farmer.csv")
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64

# %%
df['label'].nunique()
# Out:
# 22

# %%
rice = df[df['label'] =='rice']
rice.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
coconut = df[df['label'] =='coconut']
coconut.head()
# Out:
#        N   P   K  temperature   humidity        ph    rainfall    label
# 1800  18  30  29    26.762749  92.860569  6.420019  224.590366  coconut
# 1801  37  23  28    25.612944  94.313884  5.740055  224.320676  coconut
# 1802  13  28  33    28.130115  95.648076  5.686973  151.076190  coconut
# 1803   2  21  35    25.028872  91.537209  6.293662  179.824894  coconut
# 1804  10  18  35    27.797977  99.645730  6.381975  181.694228  coconut

# %%
rice['temperature'].mean()
# Out:
# 23.6893322105

# %%
coconut['temperature'].mean()
# Out:
# 27.409892172299998

# %%
rice['N'].mean()
# Out:
# 79.89

# %%
coconut['N'].mean()
# Out:
# 21.98

# %%
grouped = df.groupby('label')

# %%
grouped[['temperature']].mean()
# Out:
#              temperature
# label
# apple          22.630942
# banana         27.376798
# blackgram      29.973340
# chickpea       18.872847
# coconut        27.409892
# coffee         25.540477
# cotton         23.988958
# grapes         23.849575
# jute           24.958376
# kidneybeans    20.115085
# lentil         24.509052
# maize          22.389204
# mango          31.208770
# mothbeans      28.194920
# mungbean       28.525775
# muskmelon      28.663066
# orange         22.765725
# papaya         33.723859
# pigeonpeas     27.741762
# pomegranate    21.837842
# rice           23.689332
# watermelon     25.591767

# %%
grouped[['N']].mean()
# Out:
#                   N
# label
# apple         20.80
# banana       100.23
# blackgram     40.02
# chickpea      40.09
# coconut       21.98
# coffee       101.20
# cotton       117.77
# grapes        23.18
# jute          78.40
# kidneybeans   20.75
# lentil        18.77
# maize         77.76
# mango         20.07
# mothbeans     21.44
# mungbean      20.99
# muskmelon    100.32
# orange        19.58
# papaya        49.88
# pigeonpeas    20.73
# pomegranate   18.87
# rice          79.89
# watermelon    99.42

# %%
group = grouped['temperature'].agg(['min', 'max', 'mean'])

# %%
group.reset_index(inplace=True)
x=list(group['label'])
y=list(group['mean'])
plt.figure(figsize=(14,7))
plt.bar(x,y,ec='k',color='maroon')
plt.title("Average temperature")
plt.xlabel('Label')
plt.ylabel('min')
plt.xticks(rotation=90)
plt.show()

# %%
group.reset_index(inplace=True)
x=list(group['label'])
y=list(group['min'])
plt.figure(figsize=(14,7))
plt.bar(x,y,ec='k',color='maroon')
plt.title("Min temperature")
plt.xlabel('Label')
plt.ylabel('min')
plt.xticks(rotation=90)
plt.show()

# %%
group.reset_index(inplace=True)
x=list(group['label'])
y=list(group['max'])
plt.figure(figsize=(14,7))
plt.bar(x,y,ec='k',color='maroon')
plt.title("Max temperature")
plt.xlabel('Label')
plt.ylabel('min')
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
x = df.drop("label",axis="columns")
x.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340

# %%
sns.boxplot(df['N'])
plt.show()

# %%
sns.boxplot(df['P'])
plt.show()

# %%
sns.distplot(df['P'])
plt.show()
# Out:
# C:\Users\pawan\AppData\Local\Temp\ipykernel_12592\1814485217.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['P'])

# %%
# to normalize the outliers
from sklearn.preprocessing import StandardScaler, MinMaxScaler
std = StandardScaler()
x_transformed = std.fit_transform(x)

# %%
x_transformed
# Out:
# array([[ 1.0687974 , -0.34455075, -0.1016875 , ...,  0.47266646,
#          0.04330173,  1.8103605 ],
#        [ 0.93332887,  0.14061552, -0.14118477, ...,  0.39705125,
#          0.73487256,  2.24205791],
#        [ 0.25598625,  0.04964684, -0.08193887, ...,  0.48695381,
#          1.77151047,  2.92106603],
#        ...,
#        [ 1.82742114, -0.61745677, -0.35841972, ..., -0.19123516,
#         -0.13812031,  1.27141766],
#        [ 1.80032743, -0.64777967, -0.27942519, ..., -0.86951801,
#          0.37390383,  0.43154519],
#        [ 1.44810927, -1.07230015, -0.35841972, ..., -0.49802006,
#          0.40109573,  0.68200518]])

# %%
x_transformed.shape
# Out:
# (2200, 7)

# %%
print("total no. of clay samples: ",x_transformed.shape[0])
# Out:
# total no. of clay samples:  2200

# %%
# training and testing splitting
train = x_transformed[:2100]
test = x_transformed[2100:]

# %%
# unsupervised learning
from sklearn.cluster import KMeans
obj = KMeans()

# %%
obj.fit(train)
# Out:
# c:\Users\pawan\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans()

# %%
clust = obj.labels_

# %%
train.shape
# Out:
# (2100, 7)

# %%
y
# Out:
# [23.99686172,
#  29.90888522,
#  34.9466155,
#  20.99502153,
#  29.8690834,
#  27.92374437,
#  25.99237426,
#  41.94865736,
#  26.98582182,
#  24.92360104,
#  29.94413861,
#  26.54986394,
#  35.99009679,
#  31.99928579,
#  29.914544300000006,
#  29.94349168,
#  34.90665289,
#  43.67549305,
#  36.97794384,
#  24.96273236,
#  26.92995077,
#  26.98603693]

# %%
testing_df = x[:2100]

# %%
testing_df['cluster'] = clust
# Out:
# C:\Users\pawan\AppData\Local\Temp\ipykernel_12592\509498024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_df['cluster'] = clust

# %%
testing_df
# Out:
#        N   P   K  temperature   humidity        ph    rainfall  cluster
# 0     90  42  43    20.879744  82.002744  6.502985  202.935536        5
# 1     85  58  41    21.770462  80.319644  7.038096  226.655537        5
# 2     60  55  44    23.004459  82.320763  7.840207  263.964248        5
# 3     74  35  40    26.491096  80.158363  6.980401  242.864034        5
# 4     78  42  42    20.130175  81.604873  7.628473  262.717340        5
# ...   ..  ..  ..          ...        ...       ...         ...      ...
# 2095  87  44  43    23.874845  86.792613  6.718725  177.514731        5
# 2096  88  52  39    23.928879  88.071123  6.880205  154.660874        5
# 2097  90  39  37    24.814412  81.686889  6.861069  190.788639        5
# 2098  90  39  43    24.447439  82.286484  6.769346  190.968489        5
# 2099  84  38  43    26.574217  73.819949  7.261581  159.322307        5
#
# [2100 rows x 8 columns]

# %%
testing_df['Label'] = df[:2100]['label']
# Out:
# C:\Users\pawan\AppData\Local\Temp\ipykernel_12592\1008221603.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing_df['Label'] = df[:2100]['label']

# %%
testing_df.head(40)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall  cluster Label
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536        5  rice
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537        5  rice
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248        5  rice
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034        5  rice
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340        5  rice
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000        5  rice
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860        5  rice
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195        5  rice
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236        5  rice
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196        5  rice
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870        5  rice
# 11  90  46  42    23.978982  81.450616  7.502834  250.083234        5  rice
# 12  78  58  44    26.800796  80.886848  5.108682  284.436457        5  rice
# 13  93  56  36    24.014976  82.056872  6.984354  185.277339        5  rice
# 14  94  50  37    25.665852  80.663850  6.948020  209.586971        5  rice
# 15  60  48  39    24.282094  80.300256  7.042299  231.086335        5  rice
# 16  85  38  41    21.587118  82.788371  6.249051  276.655246        5  rice
# 17  91  35  39    23.793920  80.418180  6.970860  206.261186        5  rice
# 18  77  38  36    21.865252  80.192301  5.953933  224.555017        5  rice
# 19  88  35  40    23.579436  83.587603  5.853932  291.298662        5  rice
# 20  89  45  36    21.325042  80.474764  6.442475  185.497473        5  rice
# 21  76  40  43    25.157455  83.117135  5.070176  231.384316        5  rice
# 22  67  59  41    21.947667  80.973842  6.012633  213.356092        5  rice
# 23  83  41  43    21.052536  82.678395  6.254028  233.107582        5  rice
# 24  98  47  37    23.483813  81.332651  7.375483  224.058116        5  rice
# 25  66  53  41    25.075635  80.523891  7.778915  257.003887        5  rice
# 26  97  59  43    26.359272  84.044036  6.286500  271.358614        5  rice
# 27  97  50  41    24.529227  80.544986  7.070960  260.263403        5  rice
# 28  60  49  44    20.775761  84.497744  6.244841  240.081065        5  rice
# 29  84  51  35    22.301574  80.644165  6.043305  197.979121        5  rice
# 30  73  57  41    21.446540  84.943760  5.824709  272.201720        5  rice
# 31  92  35  40    22.179319  80.331272  6.357389  200.088279        5  rice
# 32  85  37  39    24.527837  82.736856  6.364135  224.675723        5  rice
# 33  98  53  38    20.267076  81.638952  5.014507  270.441727        5  rice
# 34  88  54  44    25.735429  83.882662  6.149411  233.132137        5  rice
# 35  95  55  42    26.795339  82.148087  5.950661  193.347399        5  rice
# 36  99  57  35    26.757542  81.177340  5.960370  272.299906        5  rice
# 37  95  39  36    23.863305  83.152508  5.561399  285.249365        5  rice
# 38  60  43  44    21.019447  82.952217  7.416245  298.401847        5  rice
# 39  63  44  41    24.172988  83.728757  5.583370  257.034355        5  rice

# %%
testing_df['cluster'].value_counts()
# Out:
# cluster
# 2    429
# 7    311
# 0    277
# 5    265
# 6    220
# 3    200
# 4    200
# 1    198
# Name: count, dtype: int64

# %%
fifth_cluster = testing_df[testing_df['cluster']== 5]

# %%
print("total point in the fifth group: ",fifth_cluster.shape[0])
# Out:
# total point in the fifth group:  265

# %%
list(fifth_cluster['Label'].unique())
# Out:
# ['rice', 'pigeonpeas', 'papaya', 'coconut', 'jute']

# %%
obj.score(train,clust)
# Out:
# -4568.984052851679

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(train,clust)*100
# Out:
# 33.77871592134806

# %%
# saving objects
import os, joblib

# %%
os.makedirs('models',exist_ok=True)
joblib.dump(obj,'./models/kmeans_model')
# Out:
# ['./models/kmeans_model']

# %%
app_data = testing_df[['cluster','Label']]
app_data.head()
# Out:
#    cluster Label
# 0        5  rice
# 1        5  rice
# 2        5  rice
# 3        5  rice
# 4        5  rice

# %%
app_data.to_csv('./models/app_data.csv', index = False)

# %%
joblib.dump(std,'./models/standard_scaler')
# Out:
# ['./models/standard_scaler']
